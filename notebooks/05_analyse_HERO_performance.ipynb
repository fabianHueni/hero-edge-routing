# %% [markdown]
# # HERO Inference Time Prediction Behaviour
# In this notebook we analyse the inference-time prediciton over time. The goal is to demonstrate that the prediction error is going down after a few rounds, as HERO manages to self-tune it's parameters via Thompson Sampling.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from utils import run_multi_run_analysis

# %%
# Batch Run with a specific list of files
FOLDER_PATH = "../results/policy_experiments/"
# Filenames included into the statistic
specific_files = [
    "boolq_lambda14.5_raw_experiment_Llama-3-2-1B-Instruct-ONNX_meta-llama-llama-3-2-1b-instruct_jseq_exponential-arrival_2026-02-27T22-02-50.csv",
    "spam_lambda13_raw_experiment_Llama-3-2-1B-Instruct-ONNX_meta-llama-llama-3-2-1b-instruct_jseq_exponential-arrival_2026-02-28T12-53-21.csv",
    "ag-news_lambda14_raw_experiment_Llama-3-2-1B-Instruct-ONNX_meta-llama-llama-3-2-1b-instruct_jseq_exponential-arrival_2026-02-28T14-54-24.csv",
    "spam_lambda8_raw_experiment_Llama-3-2-1B-Instruct-ONNX_meta-llama-llama-3-2-1b-instruct_jseq_exponential-arrival_2026-02-28T14-14-06.csv",
    "boolq_lambda10_raw_experiment_Llama-3-2-1B-Instruct-ONNX_meta-llama-llama-3-2-1b-instruct_jseq_exponential-arrival_2026-02-26T20-21-56.csv",
    "spam_lambda10_raw_experiment_Llama-3-2-1B-Instruct-ONNX_meta-llama-llama-3-2-1b-instruct_jseq_exponential-arrival_2026-02-28T13-23-52.csv"
]

file_list = [os.path.join(FOLDER_PATH, f) for f in specific_files]
run_multi_run_analysis(file_list, show_scatter=True, show_evolution=True)
# Out:
# Analyzing 6 runs...
# Saved plot: plots/time_prediction_error.pdf
# Overall MAE Inference (across all runs): 487.33 ms
# Overall MAE Total (across all runs):     727.90 ms
